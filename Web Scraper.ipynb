# %% [markdown]
# # info from my bot

# %% [raw]
# {
# ok: true,
# result: [
# {
# update_id: 907183460,
# message: {
# message_id: 4,
# from: {
# id: 1201458125,
# is_bot: false,
# first_name: "Vinay",
# last_name: "Valson",
# language_code: "en"
# },
# chat: {
# id: 1201458125,
# first_name: "Vinay",
# last_name: "Valson",
# type: "private"
# },
# date: 1596016891,
# text: "hi"
# }
# }
# ]
# }

# %%
import bs4, requests
url = 'https://aitplacements.com/'

def crawler(url):
    getPage = requests.get(url)
    getPage.raise_for_status()
    menu = bs4.BeautifulSoup(getPage.text, 'html.parser')
    for anchor in menu.findAll('a', href=True , class_="btn btn-light btn-small" , title=True):
        print(anchor['title'] + " - "+ anchor['href'])
        requests.get("https://api.telegram.org/bot1206860902:AAGTYd5yaRD6YIma28OopPx4L-h85oBIqmU/sendMessage?chat_id=1201458125&text={}".format(anchor['title'] +" - "+ anchor['href']))

crawler(url)

# %% [markdown]
# # DB Operations

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb+srv://vinay_1998:sepI6llmqwFPJWUe@bookmarker-cofya.gcp.mongodb.net/AIT_placements_bot?retryWrites=true&w=majority")
mydb = myclient["AIT_placements_bot"]
mycol = mydb["urls"]

x = mycol.find_one()

def update_db(title,url):
    print(title,"=",url)
    if mycol.find({"url":url}).count() == 0 :
        print("Url Doesnt Exist")
        data = title+"\n"+url
        send_message(bot,data)
    mycol.update({"title":title},{"$set":{"title":title,"url":url}},upsert=True)

# %% [markdown]
# # Web Crawler

# %%
import bs4, requests

def crawler():
    url = 'https://aitplacements.com/'
    getPage = requests.get(url)
    getPage.raise_for_status()
    menu = bs4.BeautifulSoup(getPage.text, 'html.parser')
    #Inside the for loop define the type of Information and tags u wanna capture from the page
    for anchor in menu.findAll('a', href=True , class_="btn btn-light btn-small" , title=True):
        update_db(anchor['title'],anchor['href'])

# %% [markdown]
# # Bot sends message

# %%
my_bots_api = '1206860902:AAGTYd5yaRD6YIma28OopPx4L-h85oBIqmU'
recievers_id = '1201458125'
bot = "https://api.telegram.org/bot"+my_bots_api+"/sendMessage?chat_id="+recievers_id+"&text="

def send_message(bot,data):
    requests.get(bot+data)

# %% [markdown]
# # Driver

# %%
import schedule
import time

schedule.every(1).minute.do(crawler)

while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# Connect wise Details = https://aitplacements.com/uncategorized/connect-wise-details/
# Url Doesnt Exist
# C:\Users\Vinay Valson\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Vinay Valson\anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   from ipykernel import kernelapp as app
# Connectwise -Invite = https://aitplacements.com/uncategorized/connectwise-invite/
# Url Doesnt Exist
# Total shortlisted students for Icertis -49 from on line test = https://aitplacements.com/uncategorized/total-shortlisted-students-for-icertis-49-from-on-line-test/
# Url Doesnt Exist
# Connect wise  – Not Under One Job policy . = https://aitplacements.com/uncategorized/connect-wise-not-under-one-job-policy/
# Url Doesnt Exist
# Mindtree Ltd = https://aitplacements.com/uncategorized/mindtree-ltd/
# Url Doesnt Exist
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-050d39badb3e> in <module>
#       6 while True:
#       7     schedule.run_pending()
# ----> 8     time.sleep(1)
#
# KeyboardInterrupt:

# %%
update_db("google","http://www.google.com")
